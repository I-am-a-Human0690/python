# %%
import matplotlib.pyplot as plt
course = ["Python","Java","C#"]
score=[80,75,50]
c=["green", "orange", "blue" ]
plt.barh(course,score,color=c,edgecolor="black",linewidth=3)#,width=0.3)
plt.xlabel("score")
plt.ylabel("course")
plt.title("Score Midterm")
plt.show()
