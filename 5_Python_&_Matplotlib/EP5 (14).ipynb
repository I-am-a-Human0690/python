# %%
import matplotlib.pyplot as plt
product1=[10,20,30,40,50]
product2=[15,38,19,20,60]
month=[1,2,3,4,5]

# %%
plt.plot(month,product1)
plt.plot(month,product2)
plt.xlabel("Month")
plt.ylabel("sales")
plt.show()

# %%
plt.savefig("EP5_savefig.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.savefig("CODE/EP5_savefig.png")
#
# File c:\Users\WTFTHE\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File c:\Users\WTFTHE\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# ...
