# %%
import matplotlib.pyplot as plt
product1=[10,20,30,40,50]
product2=[15,38,19,20,60]
month=[1,2,3,4,5]

# %%
plt.plot(month,product1,color="k",marker="x")
plt.xlabel("Month")
plt.ylabel("sales")
plt.show()
